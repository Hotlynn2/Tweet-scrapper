# %%
# Importing necessary
import credentials as c
import tweepy 
import pandas as pd

# this is for authorization
consumer_key = 'pl13zULs9D5CZvvywVw9Qe9BU'
consumer_secret = 'bWcUYdpqsjDOrgAmUV42nK81uZDi0bZ4C9RDHxDcwyUAAI8KaN'
access_token = '814433953641824256-JNNefTPysP2UVNpu4aY6Y6qDbnNydLr'
access_token_secret = '9t1WaQbco5tE8gMMLCPTl2u0AwxVNHCCmVaPZrDePywc0'

# setting up tweepy authorization 
auth = tweepy.OAuthHandler(c.consumer_key, c.consumer_secret)
auth.set_access_token(c.access_token,c.access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)


# scraping tweets from a text search query
text_query = '4more4nana'
tweets = tweepy.Cursor(api.search, q=text_query, lang='en').items(1500)

NanaAddo = []
for tweet in tweets:
    NanaAddo.append(
        {"Date": tweet.created_at, "username": tweet.user.name, "Tweet": tweet.text, "favorite_count" : tweet.favorite_count, "retweets": tweet.retweet_count, "hashtags" :tweet.entities['hashtags']})

Nana = pd.DataFrame(NanaAddo)
Nana
# Out:
#                     Date            username  \
# 0    2020-12-06 23:38:40        Content Papi
# 1    2020-12-06 23:37:01  Hon. KB Richard 🇬🇭
# 2    2020-12-06 23:32:41          Nana Adwoa
# 3    2020-12-06 23:31:08   Portgas D. Ace🔥🔥🔥
# 4    2020-12-06 23:31:02           Yng_Gucci
# ...                  ...                 ...
# 1495 2020-12-05 12:33:55    Nana Kwesi Takyi
# 1496 2020-12-05 12:33:36     Nii Odoi-Mensah
# 1497 2020-12-05 12:31:31         Mr. Skeng🏝⚡
# 1498 2020-12-05 12:29:19               Nasa💜
# 1499 2020-12-05 12:29:13    Clement Fosuhene
#
#                                                   Tweet  favorite_count  \
# 0     RT @yaa_amanfo: I do not want to step out tomo...               0
# 1     RT @HonKBRichard: @owusua_sem @NAkufoAddo Real...               0
# 2     RT @HonKBRichard: @owusua_sem @NAkufoAddo Real...               0
# 3     RT @mo_jaabs: 48 hours to Election Day you com...               0
# 4     RT @LuisPartey: Wey President this we get. E t...               0
# ...                                                 ...             ...
# 1495  The best hands to entrust the Nation's educati...               2
# 1496  @KTechgeeknerd @Cecil_Kwabena @NJOAgyemang So ...               0
# 1497  RT @DakoaNewman: Thank you my people. Yesterda...               0
# 1498  RT @DakoaNewman: Thank you my people. Yesterda...               0
# 1499  @NAkufoAddo @YouTube Indeed Nana the showboy d...               0
#
#       retweets                                           hashtags
# 0            9    [{'text': '4More4Nana', 'indices': [118, 129]}]
# 1            2      [{'text': '4More4Nana', 'indices': [57, 68]}]
# 2            2      [{'text': '4More4Nana', 'indices': [57, 68]}]
# 3           43                                                 []
# 4            0  [{'text': 'MotherSerpentOfCorruption', 'indice...
# ...        ...                                                ...
# 1495         0    [{'text': 'VoteNumber1', 'indices': [97, 109]}]
# 1496         0  [{'text': 'Vote1', 'indices': [59, 65]}, {'tex...
# 1497       197                                                 []
# 1498       197                                                 []
# 1499         0  [{'text': '4more4Nana', 'indices': [107, 118]}...
#
# [1500 rows x 6 columns]

# %%
Nana.to_excel(r'C:\Users\USER\Documents\GitHub\tweet-scrapper\extracted.xlsx', index = False)
